# %%
print ("Opening of Signal A file")
f=open("Signal 1.txt","r")
print("file opened")
line1=f.readlines()


Signal_id_A= []
Time_A= []
ColorFrom_A= []
ColorTo_A= []
EVASOverride_A= []
j=1
for i in line1:
    
    splited_data_A=i.split()
    print(Signal_id_A)  
    Signal_id_A.append(splited_data_A[0])
    Time_A.append(splited_data_A[1])
    ColorFrom_A.append(splited_data_A[2])
    ColorTo_A.append(splited_data_A[3])
    EVASOverride_A.append(splited_data_A[4])    
    j+=1
print (ColorFrom_A)
f.close()
print("File closed")

print ("Opening of Signal B file in Read Mode")
f=open("Signal B.txt","r")
print("file opened")

line2=f.readlines()


Signal_id_B= []
Time_B= []
ColorFrom_B= []
ColorTo_B= []
EVASOverride_B= []
j=1
for i in line2:
    
    splited_data_B=i.split()
    
    Signal_id_B.append(splited_data_B[0])
    Time_B.append(splited_data_B[1])
    ColorFrom_B.append(splited_data_B[2])
    ColorTo_B.append(splited_data_B[3])
    EVASOverride_B.append(splited_data_B[4])
    j+=1
f.close()
print("File closed")

print ("Opening of Signal C file in Read Mode")
f=open("Signal C.txt","r")
print("file opened")
line3=f.readlines()


Signal_id_C= []
Time_C= []
ColorFrom_C=[]
ColorTo_C= []
EVASOverride_C= []
j=1
for i in line3:
    
    splited_data_C=i.split()
    
    Signal_id_C.append(splited_data_C[0])
    Time_C.append(splited_data_C[1])
    ColorFrom_C.append(splited_data_C[2])
    ColorTo_C.append(splited_data_C[3])
    EVASOverride_C.append(splited_data_C[4])
    j+=1
f.close()
print("File closed")




with open('output.txt','a') as output:
    with open('error.txt','a') as error:
        
  
        for i in range(0,len(line1)):
            if(EVASOverride_A[i]=='No'):
                if((ColorFrom_A[i]=='Red') & (ColorTo_A[i]=='Green')):
                    print("Red to Green")
                    output.write("\n"+Signal_id_A[i]+" "+Time_A[i]+" "+ColorFrom_A[i]+" "+ColorTo_A[i]+" "+EVASOverride_A[i])
                elif((ColorFrom_A[i]=='Green') & (ColorTo_A[i]=='Amber')):
                    print("Green to Amber")
                    output.write("\n"+Signal_id_A[i]+" "+Time_A[i]+" "+ColorFrom_A[i]+" "+ColorTo_A[i]+" "+EVASOverride_A[i])
                elif((ColorFrom_A[i]=='Amber') & (ColorTo_A[i]=='Red')):
                    print("Amber to Red")
                    output.write("\n"+Signal_id_A[i]+" "+Time_A[i]+" "+ColorFrom_A[i]+" "+ColorTo_A[i]+" "+EVASOverride_A[i])
                else:
                    print("Error")
                    error.write("\n"+Signal_id_A[i]+" "+Time_A[i]+" "+ColorFrom_A[i]+" "+ColorTo_A[i]+" "+EVASOverride_A[i])
            else:
                if((ColorFrom_A[i]=='Red') & (ColorTo_A[i]=='Red')):
                    print("Red to Green")
                    output.write("\n"+Signal_id_A[i]+" "+Time_A[i]+" "+ColorFrom_A[i]+" "+ColorTo_A[i]+" "+EVASOverride_A[i])
                elif((ColorFrom_A[i]=='Green') & (ColorTo_A[i]=='Red')):
                    print("Green to Amber")
                    output.write("\n"+Signal_id_A[i]+" "+Time_A[i]+" "+ColorFrom_A[i]+" "+ColorTo_A[i]+" "+EVASOverride_A[i])
                elif((ColorFrom_A[i]=='Amber') & (ColorTo_A[i]=='Red')):
                    print("Amber to Red")
                    output.write("\n"+Signal_id_A[i]+" "+Time_A[i]+" "+ColorFrom_A[i]+" "+ColorTo_A[i]+" "+EVASOverride_A[i])
                else:
                    print("Error")
                    error.write("\n"+Signal_id_A[i]+" "+Time_A[i]+" "+ColorFrom_A[i]+" "+ColorTo_A[i]+" "+EVASOverride_A[i])
                    
                    
                    
            if(EVASOverride_B[i]=='No'):
                if((ColorFrom_B[i]=='Red') & (ColorTo_B[i]=='Green')):
                    print("Red to Green")
                    output.write("\n"+Signal_id_B[i]+" "+Time_B[i]+" "+ColorFrom_B[i]+" "+ColorTo_B[i]+" "+EVASOverride_B[i])
                elif((ColorFrom_B[i]=='Green') & (ColorTo_B[i]=='Amber')):
                    print("Green to Amber")
                    output.write("\n"+Signal_id_B[i]+" "+Time_B[i]+" "+ColorFrom_B[i]+" "+ColorTo_B[i]+" "+EVASOverride_B[i])
                elif((ColorFrom_B[i]=='Amber') & (ColorTo_B[i]=='Red')):
                    print("Amber to Red")
                    output.write("\n"+Signal_id_B[i]+" "+Time_B[i]+" "+ColorFrom_B[i]+" "+ColorTo_B[i]+" "+EVASOverride_B[i])
                else:
                    print("Error")
                    error.write("\n"+Signal_id_B[i]+" "+Time_B[i]+" "+ColorFrom_B[i]+" "+ColorTo_B[i]+" "+EVASOverride_B[i])
            else:
                if((ColorFrom_B[i]=='Red') & (ColorTo_B[i]=='Red')):
                    print("Red to Green")
                    output.write("\n"+Signal_id_B[i]+" "+Time_B[i]+" "+ColorFrom_B[i]+" "+ColorTo_B[i]+" "+EVASOverride_B[i])
                elif((ColorFrom_B[i]=='Green') & (ColorTo_B[i]=='Red')):
                    print("Green to Amber")
                    output.write("\n"+Signal_id_B[i]+" "+Time_B[i]+" "+ColorFrom_B[i]+" "+ColorTo_B[i]+" "+EVASOverride_B[i])
                elif((ColorFrom_B[i]=='Amber') & (ColorTo_B[i]=='Red')):
                    print("Amber to Red")
                    output.write("\n"+Signal_id_B[i]+" "+Time_B[i]+" "+ColorFrom_B[i]+" "+ColorTo_B[i]+" "+EVASOverride_B[i])
                else:
                    print("Error")
                    error.write("\n"+Signal_id_B[i]+" "+Time_B[i]+" "+ColorFrom_B[i]+" "+ColorTo_B[i]+" "+EVASOverride_B[i])
                    
                    
                    
            if(EVASOverride_C[i]=='No'):
                if((ColorFrom_C[i]=='Red') & (ColorTo_C[i]=='Green')):
                    print("Red to Green")
                    output.write("\n"+Signal_id_C[i]+" "+Time_C[i]+" "+ColorFrom_C[i]+" "+ColorTo_C[i]+" "+EVASOverride_C[i])
                elif((ColorFrom_C[i]=='Green') & (ColorTo_C[i]=='Amber')):
                    print("Green to Amber")
                    output.write("\n"+Signal_id_C[i]+" "+Time_C[i]+" "+ColorFrom_C[i]+" "+ColorTo_C[i]+" "+EVASOverride_C[i])
                elif((ColorFrom_C[i]=='Amber') & (ColorTo_C[i]=='Red')):
                    print("Amber to Red")
                    output.write("\n"+Signal_id_C[i]+" "+Time_C[i]+" "+ColorFrom_C[i]+" "+ColorTo_C[i]+" "+EVASOverride_C[i])
                else:
                    print("Error")
                    error.write("\n"+Signal_id_C[i]+" "+Time_C[i]+" "+ColorFrom_C[i]+" "+ColorTo_C[i]+" "+EVASOverride_C[i])
            else:
                if((ColorFrom_C[i]=='Red') & (ColorTo_C[i]=='Red')):
                    print("Red to Green")
                    output.write("\n"+Signal_id_C[i]+" "+Time_C[i]+" "+ColorFrom_C[i]+" "+ColorTo_C[i]+" "+EVASOverride_C[i])
                elif((ColorFrom_C[i]=='Green') & (ColorTo_C[i]=='Red')):
                    print("Green to Amber")
                    output.write("\n"+Signal_id_C[i]+" "+Time_C[i]+" "+ColorFrom_C[i]+" "+ColorTo_C[i]+" "+EVASOverride_C[i])
                elif((ColorFrom_C[i]=='Amber') & (ColorTo_C[i]=='Red')):
                    print("Amber to Red")
                    output.write("\n"+Signal_id_C[i]+" "+Time_C[i]+" "+ColorFrom_C[i]+" "+ColorTo_C[i]+" "+EVASOverride_C[i])
                else:
                    print("Error")
                    error.write("\n"+Signal_id_C[i]+" "+Time_C[i]+" "+ColorFrom_C[i]+" "+ColorTo_C[i]+" "+EVASOverride_C[i])
# Out:
# Opening of Signal A file
# file opened
# []
# ['S01']
# ['S01', 'S01']
# ['S01', 'S01', 'S01']
# ['S01', 'S01', 'S01', 'S01']
# ['S01', 'S01', 'S01', 'S01', 'S01']
# ['S01', 'S01', 'S01', 'S01', 'S01', 'S01']
# ['S01', 'S01', 'S01', 'S01', 'S01', 'S01', 'S01']
# ['Red', 'Amber', 'Green', 'Green', 'Green', 'Red', 'Red', 'Green']
# File closed
# Opening of Signal B file in Read Mode
# file opened
# File closed
# Opening of Signal C file in Read Mode
# file opened
# File closed
# Red to Green
# Amber to Red
# Amber to Red
# Amber to Red
# Green to Amber
# Green to Amber
# Green to Amber
# Red to Green
# Amber to Red
# Green to Amber
# Amber to Red
# Green to Amber
# Green to Amber
# Green to Amber
# Red to Green
# Red to Green
# Red to Green
# Red to Green
# Error
# Error
# Error
# Error
# Error
# Error
